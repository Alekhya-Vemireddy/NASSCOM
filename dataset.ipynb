# %% [markdown]
# <a href="https://colab.research.google.com/github/Alekhya-Vemireddy/NASSCOM/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/dataset.csv")
df.head()
# Out:
#    R.No  Rollno     Name Year
# 0     1     501  Alekhya   II
# 1     2     502  Pranavi   II
# 2     3     503   Sravya   II
# 3     4     504    Deepu   II
